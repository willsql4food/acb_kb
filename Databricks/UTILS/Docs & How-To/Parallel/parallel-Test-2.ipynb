# %% [markdown]
# # Parallel Test 2

# %%
import time

dbutils.widgets.text('testString', 'default', 'Test String')
dbutils.widgets.text('delaySeconds', '3', 'Delay (Seconds)')

# %%
nbInfo = "Parallel Test Notebook #2" 
testString = dbutils.widgets.get('testString')
delaySeconds = int(dbutils.widgets.get('delaySeconds'))

assert delaySeconds > 0, f"Delay must be a positive integer ({delaySeconds} provided)"

print(f"{nbInfo}\n\tYou passed in testString: '{testString}' with a delay of {delaySeconds} seconds\n\tProcessing...\n")

time.sleep(delaySeconds)

print(f"{nbInfo}\n\tFinished")
