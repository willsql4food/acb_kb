# %% [markdown]
# # Parallel Test 1

# %%
import time

dbutils.widgets.text('testString', 'default', 'Test String')

# %%
nbInfo = "Parallel Test Notebook #1" 
testString = dbutils.widgets.get('testString')

print(f"{nbInfo}\n\tYou passed in testString: '{testString}'\n\tProcessing...\n")

time.sleep(5)

print(f"{nbInfo}\n\tFinished")
