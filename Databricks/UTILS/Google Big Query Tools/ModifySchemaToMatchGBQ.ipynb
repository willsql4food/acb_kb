# %% [markdown]
# # Respond to Google adding fields
# Put a code block for each schema evolution, new ones right before "Figure out needed actions" section

# %%
dbutils.widgets.text("environment", "", "Dev / QA / Prod")
environment = dbutils.widgets.get("environment")
if environment == 'sbx':
    spark.sql(f"use catalog hive_metastore;")
    spark.sql("use schema default;")
else:
    spark.sql(f"use catalog bronze_{environment};")
    spark.sql("use schema googleanalytics;")

# %%
# Beginning with [events_20240711] six new columns were added:
cols = [
        'collected_traffic_source__manual_source_platform'
    ,   'collected_traffic_source__manual_creative_format'
    ,   'collected_traffic_source__manual_marketing_tactic'
    ,   'batch_event_index'
    ,   'batch_page_id'
    ,   'batch_ordering_id'
    ]

# Define the command to add these columns if needed
cmd = """alter table ga_events 
  add column collected_traffic_source__manual_source_platform string
        ,   collected_traffic_source__manual_creative_format string
        ,   collected_traffic_source__manual_marketing_tactic string
        ,   batch_event_index bigint
        ,   batch_page_id bigint
        ,   batch_ordering_id bigint"""

# %%
# Beginning with [events_20240716] 15 new columns were added:
cols = [
    'session_traffic_source_last_click__manual_campaign__campaign_id'
,   'session_traffic_source_last_click__manual_campaign__campaign_name'
,   'session_traffic_source_last_click__manual_campaign__source'
,   'session_traffic_source_last_click__manual_campaign__medium'
,   'session_traffic_source_last_click__manual_campaign__term'
,   'session_traffic_source_last_click__manual_campaign__content'
,   'session_traffic_source_last_click__manual_campaign__source_platform'
,   'session_traffic_source_last_click__manual_campaign__creative_format'
,   'session_traffic_source_last_click__manual_campaign__marketing_tactic'
,   'session_traffic_source_last_click__google_ads_campaign__customer_id'
,   'session_traffic_source_last_click__google_ads_campaign__account_name'
,   'session_traffic_source_last_click__google_ads_campaign__campaign_id'
,   'session_traffic_source_last_click__google_ads_campaign__campaign_name'
,   'session_traffic_source_last_click__google_ads_campaign__ad_group_id'
,   'session_traffic_source_last_click__google_ads_campaign__ad_group_name'
    ]

# Define the command to add these columns if needed
cmd = """alter table ga_events 
  add column session_traffic_source_last_click__manual_campaign__campaign_id string
        ,   session_traffic_source_last_click__manual_campaign__campaign_name string
        ,   session_traffic_source_last_click__manual_campaign__source string
        ,   session_traffic_source_last_click__manual_campaign__medium string
        ,   session_traffic_source_last_click__manual_campaign__term string
        ,   session_traffic_source_last_click__manual_campaign__content string
        ,   session_traffic_source_last_click__manual_campaign__source_platform string
        ,   session_traffic_source_last_click__manual_campaign__creative_format string
        ,   session_traffic_source_last_click__manual_campaign__marketing_tactic string
        ,   session_traffic_source_last_click__google_ads_campaign__customer_id string
        ,   session_traffic_source_last_click__google_ads_campaign__account_name string
        ,   session_traffic_source_last_click__google_ads_campaign__campaign_id string
        ,   session_traffic_source_last_click__google_ads_campaign__campaign_name string
        ,   session_traffic_source_last_click__google_ads_campaign__ad_group_id string
        ,   session_traffic_source_last_click__google_ads_campaign__ad_group_name string"""

# %%
# Beginning with [events_20241004] 4 new columns were added:
cols = [
        'publisher__ad_revenue_in_usd'
    ,   'publisher__ad_format'
    ,   'publisher__ad_source_name'
    ,   'publisher__ad_unit_id'
    ]

# Define the command to add these columns if needed
cmd = """alter table ga_events 
  add column publisher__ad_revenue_in_usd double
    ,   publisher__ad_format string
    ,   publisher__ad_source_name string
    ,   publisher__ad_unit_id string """

# %%
# Beginning with [events_20241009] 58 new columns were added:
cols = [
        'session_traffic_source_last_click__cross_channel_campaign'
    ,   'session_traffic_source_last_click__cross_channel_campaign__campaign_id'
    ,   'session_traffic_source_last_click__cross_channel_campaign__campaign_name'
    ,   'session_traffic_source_last_click__cross_channel_campaign__source'
    ,   'session_traffic_source_last_click__cross_channel_campaign__medium'
    ,   'session_traffic_source_last_click__cross_channel_campaign__source_platform'
    ,   'session_traffic_source_last_click__cross_channel_campaign__default_channel_group'
    ,   'session_traffic_source_last_click__cross_channel_campaign__primary_channel_group'
    ,   'session_traffic_source_last_click__sa360_campaign'
    ,   'session_traffic_source_last_click__sa360_campaign__campaign_id'
    ,   'session_traffic_source_last_click__sa360_campaign__campaign_name'
    ,   'session_traffic_source_last_click__sa360_campaign__source'
    ,   'session_traffic_source_last_click__sa360_campaign__medium'
    ,   'session_traffic_source_last_click__sa360_campaign__ad_group_id'
    ,   'session_traffic_source_last_click__sa360_campaign__ad_group_name'
    ,   'session_traffic_source_last_click__sa360_campaign__creative_format'
    ,   'session_traffic_source_last_click__sa360_campaign__engine_account_name'
    ,   'session_traffic_source_last_click__sa360_campaign__engine_account_type'
    ,   'session_traffic_source_last_click__sa360_campaign__manager_account_name'
    ,   'session_traffic_source_last_click__cm360_campaign'
    ,   'session_traffic_source_last_click__cm360_campaign__campaign_id'
    ,   'session_traffic_source_last_click__cm360_campaign__campaign_name'
    ,   'session_traffic_source_last_click__cm360_campaign__source'
    ,   'session_traffic_source_last_click__cm360_campaign__medium'
    ,   'session_traffic_source_last_click__cm360_campaign__account_id'
    ,   'session_traffic_source_last_click__cm360_campaign__account_name'
    ,   'session_traffic_source_last_click__cm360_campaign__advertiser_id'
    ,   'session_traffic_source_last_click__cm360_campaign__advertiser_name'
    ,   'session_traffic_source_last_click__cm360_campaign__creative_id'
    ,   'session_traffic_source_last_click__cm360_campaign__creative_format'
    ,   'session_traffic_source_last_click__cm360_campaign__creative_name'
    ,   'session_traffic_source_last_click__cm360_campaign__creative_type'
    ,   'session_traffic_source_last_click__cm360_campaign__creative_type_id'
    ,   'session_traffic_source_last_click__cm360_campaign__creative_version'
    ,   'session_traffic_source_last_click__cm360_campaign__placement_id'
    ,   'session_traffic_source_last_click__cm360_campaign__placement_cost_structure'
    ,   'session_traffic_source_last_click__cm360_campaign__placement_name'
    ,   'session_traffic_source_last_click__cm360_campaign__rendering_id'
    ,   'session_traffic_source_last_click__cm360_campaign__site_id'
    ,   'session_traffic_source_last_click__cm360_campaign__site_name'
    ,   'session_traffic_source_last_click__dv360_campaign'
    ,   'session_traffic_source_last_click__dv360_campaign__campaign_id'
    ,   'session_traffic_source_last_click__dv360_campaign__campaign_name'
    ,   'session_traffic_source_last_click__dv360_campaign__source'
    ,   'session_traffic_source_last_click__dv360_campaign__medium'
    ,   'session_traffic_source_last_click__dv360_campaign__advertiser_id'
    ,   'session_traffic_source_last_click__dv360_campaign__advertiser_name'
    ,   'session_traffic_source_last_click__dv360_campaign__creative_id'
    ,   'session_traffic_source_last_click__dv360_campaign__creative_format'
    ,   'session_traffic_source_last_click__dv360_campaign__creative_name'
    ,   'session_traffic_source_last_click__dv360_campaign__exchange_id'
    ,   'session_traffic_source_last_click__dv360_campaign__exchange_name'
    ,   'session_traffic_source_last_click__dv360_campaign__insertion_order_id'
    ,   'session_traffic_source_last_click__dv360_campaign__insertion_order_name'
    ,   'session_traffic_source_last_click__dv360_campaign__line_item_id'
    ,   'session_traffic_source_last_click__dv360_campaign__line_item_name'
    ,   'session_traffic_source_last_click__dv360_campaign__partner_id'
    ,   'session_traffic_source_last_click__dv360_campaign__partner_name'
    ]

# Define the command to add these columns if needed
cmd = """alter table ga_events add column 
        session_traffic_source_last_click__cross_channel_campaign string
    ,   session_traffic_source_last_click__cross_channel_campaign__campaign_id string
    ,   session_traffic_source_last_click__cross_channel_campaign__campaign_name string
    ,   session_traffic_source_last_click__cross_channel_campaign__source string
    ,   session_traffic_source_last_click__cross_channel_campaign__medium string
    ,   session_traffic_source_last_click__cross_channel_campaign__source_platform string
    ,   session_traffic_source_last_click__cross_channel_campaign__default_channel_group string
    ,   session_traffic_source_last_click__cross_channel_campaign__primary_channel_group string
    ,   session_traffic_source_last_click__sa360_campaign string
    ,   session_traffic_source_last_click__sa360_campaign__campaign_id string
    ,   session_traffic_source_last_click__sa360_campaign__campaign_name string
    ,   session_traffic_source_last_click__sa360_campaign__source string
    ,   session_traffic_source_last_click__sa360_campaign__medium string
    ,   session_traffic_source_last_click__sa360_campaign__ad_group_id string
    ,   session_traffic_source_last_click__sa360_campaign__ad_group_name string
    ,   session_traffic_source_last_click__sa360_campaign__creative_format string
    ,   session_traffic_source_last_click__sa360_campaign__engine_account_name string
    ,   session_traffic_source_last_click__sa360_campaign__engine_account_type string
    ,   session_traffic_source_last_click__sa360_campaign__manager_account_name string
    ,   session_traffic_source_last_click__cm360_campaign string
    ,   session_traffic_source_last_click__cm360_campaign__campaign_id string
    ,   session_traffic_source_last_click__cm360_campaign__campaign_name string
    ,   session_traffic_source_last_click__cm360_campaign__source string
    ,   session_traffic_source_last_click__cm360_campaign__medium string
    ,   session_traffic_source_last_click__cm360_campaign__account_id string
    ,   session_traffic_source_last_click__cm360_campaign__account_name string
    ,   session_traffic_source_last_click__cm360_campaign__advertiser_id string
    ,   session_traffic_source_last_click__cm360_campaign__advertiser_name string
    ,   session_traffic_source_last_click__cm360_campaign__creative_id string
    ,   session_traffic_source_last_click__cm360_campaign__creative_format string
    ,   session_traffic_source_last_click__cm360_campaign__creative_name string
    ,   session_traffic_source_last_click__cm360_campaign__creative_type string
    ,   session_traffic_source_last_click__cm360_campaign__creative_type_id string
    ,   session_traffic_source_last_click__cm360_campaign__creative_version string
    ,   session_traffic_source_last_click__cm360_campaign__placement_id string
    ,   session_traffic_source_last_click__cm360_campaign__placement_cost_structure string
    ,   session_traffic_source_last_click__cm360_campaign__placement_name string
    ,   session_traffic_source_last_click__cm360_campaign__rendering_id string
    ,   session_traffic_source_last_click__cm360_campaign__site_id string
    ,   session_traffic_source_last_click__cm360_campaign__site_name string
    ,   session_traffic_source_last_click__dv360_campaign string
    ,   session_traffic_source_last_click__dv360_campaign__campaign_id string
    ,   session_traffic_source_last_click__dv360_campaign__campaign_name string
    ,   session_traffic_source_last_click__dv360_campaign__source string
    ,   session_traffic_source_last_click__dv360_campaign__medium string
    ,   session_traffic_source_last_click__dv360_campaign__advertiser_id string
    ,   session_traffic_source_last_click__dv360_campaign__advertiser_name string
    ,   session_traffic_source_last_click__dv360_campaign__creative_id string
    ,   session_traffic_source_last_click__dv360_campaign__creative_format string
    ,   session_traffic_source_last_click__dv360_campaign__creative_name string
    ,   session_traffic_source_last_click__dv360_campaign__exchange_id string
    ,   session_traffic_source_last_click__dv360_campaign__exchange_name string
    ,   session_traffic_source_last_click__dv360_campaign__insertion_order_id string
    ,   session_traffic_source_last_click__dv360_campaign__insertion_order_name string
    ,   session_traffic_source_last_click__dv360_campaign__line_item_id string
    ,   session_traffic_source_last_click__dv360_campaign__line_item_name string
    ,   session_traffic_source_last_click__dv360_campaign__partner_id string
    ,   session_traffic_source_last_click__dv360_campaign__partner_name string """

# %% [markdown]
# ## Figure out needed actions

# %%
# Filter the table definition to only those columns (if they even exist yet)
tbldef = spark.sql('describe table ga_events').where(f"col_name in ({str(cols)[1:-1]})")

# Three possibilities:
# 1 - None of these columns exist, so above command is appropriate
if tbldef.count() == 0:
    print(cmd)

# 2 - Some, but not all exist - will need manual intervention
elif tbldef.count() < len(cols):
    print(f"""These columns already exist:
{tbldef.select("col_name").collect()}
=======================================================          
Modify the following command and execute as needed: 
**************************
{cmd}
**************************
""")

# 3 - All of them exist, so nothing to do here - it's already done
else:
    print("Schema is current.")

# %% [markdown]
# # Do the work - replace this command as needed

# %%
# %sql
/*
alter table ga_events 
  add column collected_traffic_source__manual_source_platform string
        ,   collected_traffic_source__manual_creative_format string
        ,   collected_traffic_source__manual_marketing_tactic string
        ,   batch_event_index bigint
        ,   batch_page_id bigint
        ,   batch_ordering_id bigint;

alter table ga_events 
  add column session_traffic_source_last_click__manual_campaign__campaign_id string
        ,   session_traffic_source_last_click__manual_campaign__campaign_name string
        ,   session_traffic_source_last_click__manual_campaign__source string
        ,   session_traffic_source_last_click__manual_campaign__medium string
        ,   session_traffic_source_last_click__manual_campaign__term string
        ,   session_traffic_source_last_click__manual_campaign__content string
        ,   session_traffic_source_last_click__manual_campaign__source_platform string
        ,   session_traffic_source_last_click__manual_campaign__creative_format string
        ,   session_traffic_source_last_click__manual_campaign__marketing_tactic string
        ,   session_traffic_source_last_click__google_ads_campaign__customer_id string
        ,   session_traffic_source_last_click__google_ads_campaign__account_name string
        ,   session_traffic_source_last_click__google_ads_campaign__campaign_id string
        ,   session_traffic_source_last_click__google_ads_campaign__campaign_name string
        ,   session_traffic_source_last_click__google_ads_campaign__ad_group_id string
        ,   session_traffic_source_last_click__google_ads_campaign__ad_group_name string

alter table ga_events 
  add column publisher__ad_revenue_in_usd double
    ,   publisher__ad_format string
    ,   publisher__ad_source_name string
    ,   publisher__ad_unit_id string 
*/
alter table ga_events add column 
        session_traffic_source_last_click__cross_channel_campaign string
    ,   session_traffic_source_last_click__cross_channel_campaign__campaign_id string
    ,   session_traffic_source_last_click__cross_channel_campaign__campaign_name string
    ,   session_traffic_source_last_click__cross_channel_campaign__source string
    ,   session_traffic_source_last_click__cross_channel_campaign__medium string
    ,   session_traffic_source_last_click__cross_channel_campaign__source_platform string
    ,   session_traffic_source_last_click__cross_channel_campaign__default_channel_group string
    ,   session_traffic_source_last_click__cross_channel_campaign__primary_channel_group string
    ,   session_traffic_source_last_click__sa360_campaign string
    ,   session_traffic_source_last_click__sa360_campaign__campaign_id string
    ,   session_traffic_source_last_click__sa360_campaign__campaign_name string
    ,   session_traffic_source_last_click__sa360_campaign__source string
    ,   session_traffic_source_last_click__sa360_campaign__medium string
    ,   session_traffic_source_last_click__sa360_campaign__ad_group_id string
    ,   session_traffic_source_last_click__sa360_campaign__ad_group_name string
    ,   session_traffic_source_last_click__sa360_campaign__creative_format string
    ,   session_traffic_source_last_click__sa360_campaign__engine_account_name string
    ,   session_traffic_source_last_click__sa360_campaign__engine_account_type string
    ,   session_traffic_source_last_click__sa360_campaign__manager_account_name string
    ,   session_traffic_source_last_click__cm360_campaign string
    ,   session_traffic_source_last_click__cm360_campaign__campaign_id string
    ,   session_traffic_source_last_click__cm360_campaign__campaign_name string
    ,   session_traffic_source_last_click__cm360_campaign__source string
    ,   session_traffic_source_last_click__cm360_campaign__medium string
    ,   session_traffic_source_last_click__cm360_campaign__account_id string
    ,   session_traffic_source_last_click__cm360_campaign__account_name string
    ,   session_traffic_source_last_click__cm360_campaign__advertiser_id string
    ,   session_traffic_source_last_click__cm360_campaign__advertiser_name string
    ,   session_traffic_source_last_click__cm360_campaign__creative_id string
    ,   session_traffic_source_last_click__cm360_campaign__creative_format string
    ,   session_traffic_source_last_click__cm360_campaign__creative_name string
    ,   session_traffic_source_last_click__cm360_campaign__creative_type string
    ,   session_traffic_source_last_click__cm360_campaign__creative_type_id string
    ,   session_traffic_source_last_click__cm360_campaign__creative_version string
    ,   session_traffic_source_last_click__cm360_campaign__placement_id string
    ,   session_traffic_source_last_click__cm360_campaign__placement_cost_structure string
    ,   session_traffic_source_last_click__cm360_campaign__placement_name string
    ,   session_traffic_source_last_click__cm360_campaign__rendering_id string
    ,   session_traffic_source_last_click__cm360_campaign__site_id string
    ,   session_traffic_source_last_click__cm360_campaign__site_name string
    ,   session_traffic_source_last_click__dv360_campaign string
    ,   session_traffic_source_last_click__dv360_campaign__campaign_id string
    ,   session_traffic_source_last_click__dv360_campaign__campaign_name string
    ,   session_traffic_source_last_click__dv360_campaign__source string
    ,   session_traffic_source_last_click__dv360_campaign__medium string
    ,   session_traffic_source_last_click__dv360_campaign__advertiser_id string
    ,   session_traffic_source_last_click__dv360_campaign__advertiser_name string
    ,   session_traffic_source_last_click__dv360_campaign__creative_id string
    ,   session_traffic_source_last_click__dv360_campaign__creative_format string
    ,   session_traffic_source_last_click__dv360_campaign__creative_name string
    ,   session_traffic_source_last_click__dv360_campaign__exchange_id string
    ,   session_traffic_source_last_click__dv360_campaign__exchange_name string
    ,   session_traffic_source_last_click__dv360_campaign__insertion_order_id string
    ,   session_traffic_source_last_click__dv360_campaign__insertion_order_name string
    ,   session_traffic_source_last_click__dv360_campaign__line_item_id string
    ,   session_traffic_source_last_click__dv360_campaign__line_item_name string
    ,   session_traffic_source_last_click__dv360_campaign__partner_id string
    ,   session_traffic_source_last_click__dv360_campaign__partner_name string
